# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
merged_all=pd.read_csv('/data/merge_all.csv', index_col='TransientID')
merged_all.head()
# Out:
#                     Classification  Dec (J2000) SDSS  count  mag_info  \
# TransientID
# 1210061091254108515             SN      8.91432  yes    196     18.31
# 1305091120654118444             SN     12.25101  yes     44     18.88
# 1007051071254133856             SN      8.00804  yes      9     19.08
# 1408311210014119351         Blazar     20.79720  yes    255     17.60
# 1502071150154145908            HPM     16.86533   no     13     12.52
#
#                      mag_max   mag_mean  mag_median  mag_min   mag_std  \
# TransientID
# 1210061091254108515  21.3838  19.579940    19.67260  12.2208  0.826791
# 1305091120654118444  21.5437  20.017727    20.36435  12.4589  1.414599
# 1007051071254133856  21.3105  18.760311    19.05830  12.4652  2.544812
# 1408311210014119351  20.3146  18.769760    18.89440  11.6801  1.023209
# 1502071150154145908  20.8485  13.004977    12.35530  12.3152  2.356798
#
#                      magerr_max  magerr_mean  magerr_std     mjd_std  SN  \
# TransientID
# ...

# %%
merged_all.shape
# Out:
# (3861, 17)

# %%
merged_all.columns
# Out:
# Index(['Classification', 'Dec (J2000)', 'SDSS', 'count', 'mag_info', 'mag_max',
#        'mag_mean', 'mag_median', 'mag_min', 'mag_std', 'magerr_max',
#        'magerr_mean', 'magerr_std', 'mjd_std', 'SN', 'baseline',
#        'mag_baseline'],
#       dtype='str')

# %%
merged_all.dtypes
# Out:
# Classification        str
# Dec (J2000)       float64
# SDSS                  str
# count               int64
# mag_info          float64
# mag_max           float64
# mag_mean          float64
# mag_median        float64
# mag_min           float64
# mag_std           float64
# magerr_max        float64
# magerr_mean       float64
# magerr_std        float64
# mjd_std           float64
# SN                  int64
# baseline          float64
# mag_baseline      float64
# dtype: object

# %%
merged_all.describe(include='all')
# Out:
#        Classification  Dec (J2000)  SDSS        count     mag_info  \
# count            3861  3861.000000  3861  3861.000000  3861.000000
# unique             31          NaN     2          NaN          NaN
# top                SN          NaN   yes          NaN          NaN
# freq             1537          NaN  2934          NaN          NaN
# mean              NaN    16.685183   NaN   103.246568    17.674556
# std               NaN    20.018069   NaN   116.817806     1.778483
# min               NaN   -28.110910   NaN     1.000000    12.010000
# 25%               NaN     1.134370   NaN    12.000000    16.820000
# 50%               NaN    16.805390   NaN    45.000000    18.170000
# 75%               NaN    31.686380   NaN   171.000000    18.940000
# max               NaN    69.945920   NaN   564.000000    20.720000
#
#             mag_max     mag_mean   mag_median      mag_min      mag_std  \
# count   3861.000000  3861.000000  3861.000000  3861.000000  3734.000000
# ...

# %%
merged_all.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3861 entries, 1210061091254108515 to 904031010684129833
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Classification  3861 non-null   str
#  1   Dec (J2000)     3861 non-null   float64
#  2   SDSS            3861 non-null   str
#  3   count           3861 non-null   int64
#  4   mag_info        3861 non-null   float64
#  5   mag_max         3861 non-null   float64
#  6   mag_mean        3861 non-null   float64
#  7   mag_median      3861 non-null   float64
#  8   mag_min         3861 non-null   float64
#  9   mag_std         3734 non-null   float64
#  10  magerr_max      3861 non-null   float64
#  11  magerr_mean     3861 non-null   float64
#  12  magerr_std      3734 non-null   float64
#  13  mjd_std         3734 non-null   float64
#  14  SN              3861 non-null   int64
#  15  baseline        3861 non-null   float64
# ...

# %%
print(merged_all['SDSS'].map(repr).unique())
# Out:
# <StringArray>
# [''yes'', ''no'']
# Length: 2, dtype: str

# %%
merged_all['SDSS'] = (
    merged_all['SDSS']
    .str.strip("'")
    .str.lower()
    .eq('yes')
    .astype(int)
)
print(merged_all['SDSS'].value_counts())
# Out:
# SDSS
# 1    2934
# 0     927
# Name: count, dtype: int64

# %%
merged_all.head()
# Out:
#                     Classification  Dec (J2000)  SDSS  count  mag_info  \
# TransientID
# 1210061091254108515             SN      8.91432     1    196     18.31
# 1305091120654118444             SN     12.25101     1     44     18.88
# 1007051071254133856             SN      8.00804     1      9     19.08
# 1408311210014119351         Blazar     20.79720     1    255     17.60
# 1502071150154145908            HPM     16.86533     0     13     12.52
#
#                      mag_max   mag_mean  mag_median  mag_min   mag_std  \
# TransientID
# 1210061091254108515  21.3838  19.579940    19.67260  12.2208  0.826791
# 1305091120654118444  21.5437  20.017727    20.36435  12.4589  1.414599
# 1007051071254133856  21.3105  18.760311    19.05830  12.4652  2.544812
# 1408311210014119351  20.3146  18.769760    18.89440  11.6801  1.023209
# 1502071150154145908  20.8485  13.004977    12.35530  12.3152  2.356798
#
#                      magerr_max  magerr_mean  magerr_std     mjd_std  SN  \
# ...

# %%
merged_all=merged_all[merged_all['count']>1]
merged_all.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3734 entries, 1210061091254108515 to 1502201230664120626
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Classification  3734 non-null   str
#  1   Dec (J2000)     3734 non-null   float64
#  2   SDSS            3734 non-null   int64
#  3   count           3734 non-null   int64
#  4   mag_info        3734 non-null   float64
#  5   mag_max         3734 non-null   float64
#  6   mag_mean        3734 non-null   float64
#  7   mag_median      3734 non-null   float64
#  8   mag_min         3734 non-null   float64
#  9   mag_std         3734 non-null   float64
#  10  magerr_max      3734 non-null   float64
#  11  magerr_mean     3734 non-null   float64
#  12  magerr_std      3734 non-null   float64
#  13  mjd_std         3734 non-null   float64
#  14  SN              3734 non-null   int64
#  15  baseline        3734 non-null   float64
# ...

# %%
merged_all.describe(include='all')
# Out:
#        Classification  Dec (J2000)         SDSS        count     mag_info  \
# count            3734  3734.000000  3734.000000  3734.000000  3734.000000
# unique             31          NaN          NaN          NaN          NaN
# top                SN          NaN          NaN          NaN          NaN
# freq             1449          NaN          NaN          NaN          NaN
# mean              NaN    16.575655     0.758168   106.724156    17.663626
# std               NaN    20.012678     0.428250   117.230111     1.784417
# min               NaN   -28.110910     0.000000     2.000000    12.010000
# 25%               NaN     1.047273     1.000000    14.000000    16.790000
# 50%               NaN    16.642115     1.000000    50.000000    18.150000
# 75%               NaN    31.550113     1.000000   176.750000    18.940000
# max               NaN    69.945920     1.000000   564.000000    20.720000
#
#             mag_max     mag_mean   mag_median      mag_min      mag_std  \
# ...

# %%
y=merged_all['SN']
X=merged_all.drop(columns=['Classification','SN'])

# %%
X.shape
# Out:
# (3734, 15)

# %%
y.shape
# Out:
# (3734,)

# %%
X.columns
# Out:
# Index(['Dec (J2000)', 'SDSS', 'count', 'mag_info', 'mag_max', 'mag_mean',
#        'mag_median', 'mag_min', 'mag_std', 'magerr_max', 'magerr_mean',
#        'magerr_std', 'mjd_std', 'baseline', 'mag_baseline'],
#       dtype='str')

# %%
y.value_counts()
# Out:
# SN
# 0    2285
# 1    1449
# Name: count, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0,stratify=y)

# %%
X_train.shape
# Out:
# (2987, 15)

# %%
X_test.shape
# Out:
# (747, 15)

# %%
y_test.value_counts()
# Out:
# SN
# 0    457
# 1    290
# Name: count, dtype: int64

# %%
y_train.value_counts()
# Out:
# SN
# 0    1828
# 1    1159
# Name: count, dtype: int64

# %%
X_test.to_csv('C:\\Users\\dawit\\PycharmProjects\\supernova\\data\\X_test.csv',index=False)
X_train.to_csv('C:\\Users\\dawit\\PycharmProjects\\supernova\\data\\X_train.csv',index=False)
y_train.to_csv('C:\\Users\\dawit\\PycharmProjects\\supernova\\data\\y_train.csv',index=False)
y_test.to_csv('C:\\Users\\dawit\\PycharmProjects\\supernova\\data\\y_test.csv',index=False)
